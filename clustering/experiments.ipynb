# %%
import pandas as pd
import pickle

# %%
test_df = pd.read_csv("source_data/triplicates_v15.csv", encoding='latin-1')
model = pickle.load(open('results/berttopic/custom_umap_gpt_bigrams_v15_50.pkl','rb'))
train_df = pd.read_csv("results/berttopic/pickled_custom_umap_gpt_bigrams_v15_500_with_class.csv", encoding='latin-1')

# %%
poem_prompt_idxs = [11,
25,
352,
358,
451,
635,
801,
875,
912,
1146,
1168,
1182,
1,
81,
122,
169,
193,
283,
323,
337,
339,
368,
391,
417,
561,
566,
631,
666,
712,
758,
796,
845,
851,
925,
959
]
poem_prompt_idxs = [x-1 for x in poem_prompt_idxs]

# %%
poems_df = test_df.iloc[test_df.index.isin(poem_prompt_idxs)]
non_poems_df = test_df.iloc[~test_df.index.isin(poem_prompt_idxs)].sample(n=len(poem_prompt_idxs))

# %%
poems_df.head()
# Out:
#      idx     score                file  \
# 1      2  0.019104  gpt_rewrittens_v15
# 11    12  0.021098  gpt_rewrittens_v15
# 25    28  0.022893  gpt_rewrittens_v15
# 81    89  0.025213  gpt_rewrittens_v15
# 122  137  0.025982  gpt_rewrittens_v15
#
#                                         rewrite_prompt   id  \
# 1    Rewrite this column with a strict adherence to...    3
# 11              Revitalize the censored word / gritty.   13
# 25   Edit it as if it centers on newly established ...   29
# 81     Edit this as if you are agreeing with yourself.   90
# 122             Edit a dialogue between organizations.  138
#
#                                          original_text category  \
# 1    That week i had also been to the gym every sin...    Blogs
# 11   Mysore. The kingdom, which was ruled by the Wo...    facts
# 25   War II. The station still operates as a radar ...    facts
# 81   Mount St. Helens. She retired after losing her...    facts
# ...

# %%
poems_preds, poems_probs = model.transform(poems_df["rewrite_prompt"])
non_poems_preds, non_poems_probs = model.transform(non_poems_df["rewrite_prompt"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/LLM Prompt Recovery/Prompt_Recovery_challenge/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ...
